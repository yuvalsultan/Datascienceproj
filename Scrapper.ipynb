# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
import json, csv
from time import sleep
import time

# %%
link = "https://www.amazon.com/"
resp = requests.get(link)
buffer = int(time.time() % 100)
if (resp.status_code == 200):

    def scrape(url):  

        headers = {
            'dnt': '1',
            'upgrade-insecure-requests': '1',
            'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.61 Safari/537.36',
            'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
            'sec-fetch-site': 'same-origin',
            'sec-fetch-mode': 'navigate',
            'sec-fetch-user': '?1',
            'sec-fetch-dest': 'document',
            'referer': 'https://www.amazon.com/',
            'accept-language': 'en-GB,en-US;q=0.9,en;q=0.8',
        }
        print("Downloading %s"%url)
        r = requests.get(url, headers=headers)
        if r.status_code > 500:
            if "To discuss automated access to Amazon data please contact" in r.text:
                print("Page %s was blocked by Amazon. Please try using better proxies\n"%url)
            else:
                print("Page %s must have been blocked by Amazon as the status code was %d"%(url,r.status_code))
            return None
        return e.extract(r.text)

    # product_data = []
    with open("urls.txt",'r') as urllist, open('output.jsonl','w') as outfile:
        for url in urllist.read().splitlines():
            data = scrape(url) 
            if data:
                json.dump(data,outfile)
                outfile.write("\n")
                sleep(5)   
else:
    link = "dataFinal.csv"
    data = pd.read_csv(link)
    data = data[buffer:]
    for index, rows in data.iterrows():
        print(rows)
        sleep(4)
    pass
# Out:
# Unnamed: 0                                                     27
# product_link    https://www.amazon.com/Products-Waterproof-Blu...
# image_link      https://m.media-amazon.com/images/I/51WwfpRBrY...
# sponsered                                                       0
# title           CD’s Products Waterproof Bluetooth Portable Sp...
# offer_price                                                 39.99
# currency                                                        $
# rating                                         3.6 out of 5 stars
# category                                              electronics
# mrp                                                          47.9
# isBestSeller                                                False
# Name: 27, dtype: object
# Unnamed: 0                                                     28
# product_link    https://www.amazon.com/Portable-Bluetooth-Wate...
# image_link      https://m.media-amazon.com/images/I/81flrf35x6...
# sponsered                                                       0
# title           ArcWave Portable Bluetooth Speaker, High Power...
# offer_price                                                 69.99
# currency                                                        $
# rating                                         4.4 out of 5 stars
# category                                              electronics
# mrp                                                          90.9
# isBestSeller                                                False
# Name: 28, dtype: object
# Unnamed: 0                                                     29
# product_link    https://www.amazon.com/Waterproof-Bluetooth-Po...
# image_link      https://m.media-amazon.com/images/I/713im7uMbg...
# sponsered                                                       0
# title           Waterproof Bluetooth Speaker, Portable Wireles...
# offer_price                                                 30.99
# currency                                                        $
# rating                                         4.9 out of 5 stars
# category                                              electronics
# mrp                                                          37.1
# isBestSeller                                                False
# Name: 29, dtype: object
# Unnamed: 0                                                     30
# product_link    https://www.amazon.com/gp/slredirect/picassoRe...
# image_link      https://m.media-amazon.com/images/I/71ctM-CgMn...
# sponsered                                                       0
# title           Outdoor Waterproof Bluetooth Speaker,Kunodi Wi...
# offer_price                                                 17.99
# currency                                                        $
# rating                                         4.5 out of 5 stars
# category                                              electronics
# mrp                                                          25.1
# isBestSeller                                                False
# Name: 30, dtype: object
# Unnamed: 0                                                     31
# product_link    https://www.amazon.com/gp/slredirect/picassoRe...
# image_link      https://m.media-amazon.com/images/I/81xF+wk2P4...
# sponsered                                                       0
# title           Norcent Dual 6.5" Inch Party Portable Bluetoot...
# offer_price                                                109.99
# currency                                                        $
# rating                                         3.9 out of 5 stars
# category                                              electronics
# mrp                                                         148.4
# isBestSeller                                                False
# Name: 31, dtype: object
# Unnamed: 0                                                     32
# product_link    https://www.amazon.com/gp/slredirect/picassoRe...
# image_link      https://m.media-amazon.com/images/I/51Y-8B9io6...
# sponsered                                                       0
# title           Bluetooth Speaker Portable, Outdoor Speaker Wi...
# offer_price                                                 28.69
# currency                                                        $
# rating                                         4.3 out of 5 stars
# category                                              electronics
# mrp                                                          34.4
# isBestSeller                                                False
# Name: 32, dtype: object
# Unnamed: 0                                                     33
# product_link    https://www.amazon.com/gp/slredirect/picassoRe...
# image_link      https://m.media-amazon.com/images/I/71RLxhnwFv...
# sponsered                                                       0
# title           Bluetooth Speaker, Waterproof Portable Bluetoo...
# offer_price                                                 20.99
# currency                                                        $
# rating                                         3.0 out of 5 stars
# category                                              electronics
# mrp                                                          29.3
# isBestSeller                                                False
# Name: 33, dtype: object
# Unnamed: 0                                                     34
# product_link    https://www.amazon.com/gp/slredirect/picassoRe...
# image_link      https://m.media-amazon.com/images/I/61KQUNYbMG...
# sponsered                                                       0
# title           Portable Bluetooth Speaker, Outdoor Speaker, M...
# offer_price                                                 24.64
# currency                                                        $
# rating                                         4.3 out of 5 stars
# category                                              electronics
# mrp                                                          34.4
# isBestSeller                                                False
# Name: 34, dtype: object
# Unnamed: 0                                                     35
# product_link    https://www.amazon.com/gp/slredirect/picassoRe...
# image_link      https://m.media-amazon.com/images/I/61Hzt-9K3A...
# sponsered                                                       0
# title           Wireless Handheld Bluetooth 3-in-1 Duet Singin...
# offer_price                                                 25.99
# currency                                                        $
# rating                                         4.3 out of 5 stars
# category                                              electronics
# mrp                                                          31.1
# isBestSeller                                                False
# Name: 35, dtype: object
# Unnamed: 0                                                     36
# product_link    https://www.amazon.com/Waterproof-Bluetooth-Sp...
# image_link      https://m.media-amazon.com/images/I/61J0YVByf8...
# sponsered                                                       0
# title           Waterproof Bluetooth Speaker Wireless Outdoor ...
# offer_price                                                  29.0
# currency                                                      NaN
# rating                                         5.0 out of 5 stars
# category                                              electronics
# mrp                                                          34.8
# isBestSeller                                                False
# Name: 36, dtype: object
# Unnamed: 0                                                     37
# product_link    https://www.amazon.com/uuffoo-Bluetooth-Speake...
# image_link      https://m.media-amazon.com/images/I/51F60XXs8d...
# sponsered                                                       0
# title           uuffoo Smart Outdoor End Table with Bluetooth ...
# offer_price                                                199.98
# currency                                                        $
# rating                                         4.3 out of 5 stars
# category                                              electronics
# mrp                                                         269.9
# isBestSeller                                                False
# Name: 37, dtype: object
# Unnamed: 0                                                     38
# product_link    https://www.amazon.com/JBL-Portable-Bluetooth-...
# image_link      https://m.media-amazon.com/images/I/61HVF2rMOu...
# sponsered                                                       0
# title           JBL Charge 3 Portable Bluetooth Waterproof Spe...
# offer_price                                                  29.0
# currency                                                      NaN
# rating                                         4.7 out of 5 stars
# category                                              electronics
# mrp                                                          34.8
# isBestSeller                                                False
# Name: 38, dtype: object
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-b27fc1063392> in <module>
#      42     for index, rows in data.iterrows():
#      43         print(rows)
# ---> 44         sleep(4)
#      45     pass
#
# KeyboardInterrupt:
