# %%
#importing the libraries
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
import json, csv
from time import sleep
import time
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
import json, csv
from time import sleep
import time
import csv
from bs4 import BeautifulSoup
from selenium import webdriver
import pandas as pd
from webdriver_manager.chrome import ChromeDriverManager
import re
import os
driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 97.0.4692
# Get LATEST chromedriver version for 97.0.4692 google-chrome
# Driver [C:\Users\talli\.wdm\drivers\chromedriver\win32\97.0.4692.71\chromedriver.exe] found in cache
# <ipython-input-8-48bc9c9751ae>:23: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())

# %%
list_of_urls = [
    'https://www.amazon.in/s?k=earphones&ref=nb_sb_noss_2'
    'https://www.amazon.in/s?k=headphones&ref=nb_sb_noss_2'
    'https://www.amazon.in/s?k=watches&ref=nb_sb_noss_2'
    'https://www.amazon.in/s?k=shirts&ref=nb_sb_noss_2'
 ]

import requests
headers = {
  'authority': 'www.amazon.in',
  'pragma': 'no-cache',
  'cache-control': 'no-cache',
  'rtt': '50',
  'downlink': '10',
  'ect': '4g',
  'upgrade-insecure-requests': '1',
  'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36',
  'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
  'sec-fetch-site': 'cross-site',
  'sec-fetch-mode': 'navigate',
  'sec-fetch-user': '?1',
  'sec-fetch-dest': 'document',
  'accept-language': 'en-IN,en-GB;q=0.9,en-US;q=0.8,en;q=0.7'
}


def getDescription(url) :
    page = requests.get(url, headers=headers)
    results = soup.find(id='productOverview_feature_div')
    return results.text

def getResults(url):
    driver.get(url)
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    results=(soup.find_all('div', {'data-component-type' : 's-search-result'}))
    return results
if(not os.path.exists("dataFinal.csv")):
    results_list = []
    for url in list_of_urls:
        results_list.append(getResults(url))

for link in list_of_urls:
    resp = requests.get(link)
    buffer = int(time.time() % 100)
    if (resp.status_code == 200):
        def createCSV(resultslist) :
            for results in resultslist:
                for item in results:
                        atag = item.h2.a
                        name = atag.text.strip()
                        url = 'http://www.amazon.in' + atag.get('href')
                        try:
                            offer_price = int(item.find('span','a-price').find('span','a-offscreen').text[1:])
                        except:
                            prioffer_pricece = np.nan
                        try:
                            img_link = int(item.find('span','a-image').find('span','a-offscreen').text[1:])
                        except:
                            img_link = np.nan
                        try:
                            mrp = int(item.find('span','a-image').find('span','a-offscreen-mrp-segment32').text[1:])
                        except:
                            mrp = np.nan
                        try: 
                            rating = item.i.text
                        except:
                            rating = ''
                        try:
                            no_of_reviews = item.find('span', {'class': 'a-size-base','dir' : 'auto'}).text
                        except:
                            no_of_reviews = ''
                        try:
                            title = item.find('span', {'class': 'a-size-desc','dir' : 'auto'}).text
                        except:
                            title = ''
                        try:
                            bseller = item.find('span', {'class': 'a-size-base-BestSeller','dir' : 'auto'})
                        except:
                            bseller = np.nan
                        try:
                            curr = item.find('span', {'class': 'a-product-country-currency','dir' : 'auto'})
                        except:
                            curr = np.nan
                        try:
                            cat = item.find('span', {'class': 'cl-category-list-option','dir' : 'auto'})
                        except:
                            cat = np.nan
                        try:
                            sponsered = item.find('span', {'class': 'a-product-spon','dir' : 'auto'})
                        except:
                            sponsered = np.nan
                        description = getDescription(url)
                        l = [item,img_link,sponsered,title,offer_price,curr,rating,cat,mrp,bseller]
                        data.append(l)
            return pd.DataFrame(data, columns = ["product_link","image_link","sponsered","title","offer_price","currency","rating","category","mrp","isBestSeller"])

    else:
        link = "dataFinal.csv"
        data = pd.read_csv(link)
        data = data[buffer:]
        for index, rows in data.iterrows():
            print(rows)
            sleep(4)
        pass
# Out:
# Unnamed: 0                                                     72
# product_link    https://www.amazon.com/Triangle-Wireless-Bluet...
# image_link      https://m.media-amazon.com/images/I/61kgGqOTu2...
# sponsered                                                       0
# title           Triangle LN01A Wireless Bluetooth Bookshelf Sp...
# offer_price                                                 649.0
# currency                                                        $
# rating                                         4.8 out of 5 stars
# category                                              electronics
# mrp                                                         876.1
# isBestSeller                                                 True
# Name: 72, dtype: object
# Unnamed: 0                                                     73
# product_link    https://www.amazon.com/Sadfuncee567-Bluetooth-...
# image_link      https://m.media-amazon.com/images/I/71I3xoou6U...
# sponsered                                                       0
# title           Sadfuncee567 Bluetooth Speakers, 26ft Bluetoot...
# offer_price                                                  50.0
# currency                                                        $
# rating                                         4.3 out of 5 stars
# category                                              electronics
# mrp                                                          60.0
# isBestSeller                                                False
# Name: 73, dtype: object
# Unnamed: 0                                                     74
# product_link    https://www.amazon.com/Hermitshell-Portable-Bl...
# image_link      https://m.media-amazon.com/images/I/61w6kUl4BC...
# sponsered                                                       0
# title           Hermitshell Hard Travel Case for Ortizan Porta...
# offer_price                                                 16.99
# currency                                                        $
# rating                                         4.6 out of 5 stars
# category                                              electronics
# mrp                                                          23.7
# isBestSeller                                                False
# Name: 74, dtype: object
# Unnamed: 0                                                     75
# product_link    https://www.amazon.com/Long-Run-Technologies-C...
# image_link      https://m.media-amazon.com/images/I/71JUcmAavL...
# sponsered                                                       0
# title           Wearable Speaker: Bluetooth Wireless Neckband ...
# offer_price                                                 39.97
# currency                                                        $
# rating                                         4.2 out of 5 stars
# category                                              electronics
# mrp                                                          47.9
# isBestSeller                                                False
# Name: 75, dtype: object
# Unnamed: 0                                                     76
# product_link    https://www.amazon.com/Edison-Professional-Blu...
# image_link      https://m.media-amazon.com/images/I/517MPFUXBc...
# sponsered                                                       0
# title           Edison Professional 10" Party System Bluetooth...
# offer_price                                                  29.0
# currency                                                      NaN
# rating                                         4.2 out of 5 stars
# category                                              electronics
# mrp                                                          34.8
# isBestSeller                                                False
# Name: 76, dtype: object
# Unnamed: 0                                                     77
# product_link    https://www.amazon.com/Bluetooth-Speakers-Port...
# image_link      https://m.media-amazon.com/images/I/61A7qXhpF4...
# sponsered                                                       0
# title           Momoho Animal Bluetooth Speakers Portable Wire...
# offer_price                                                  7.99
# currency                                                        $
# rating                                         4.3 out of 5 stars
# category                                              electronics
# mrp                                                           9.9
# isBestSeller                                                False
# Name: 77, dtype: object
# Unnamed: 0                                                     78
# product_link    https://www.amazon.com/BOGASING-M10-Bluetooth-...
# image_link      https://m.media-amazon.com/images/I/71qgc4sddc...
# sponsered                                                       0
# title           BOGASING M10 Portable Bluetooth Speaker, IPX7 ...
# offer_price                                                 34.99
# currency                                                        $
# rating                                         4.8 out of 5 stars
# category                                              electronics
# mrp                                                          41.9
# isBestSeller                                                False
# Name: 78, dtype: object
# Unnamed: 0                                                     79
# product_link    https://www.amazon.com/Monoprice-Wireless-Blue...
# image_link      https://m.media-amazon.com/images/I/51h889Unb+...
# sponsered                                                       0
# title           Monoprice True Wireless Stereo Bluetooth Speak...
# offer_price                                                190.45
# currency                                                        $
# rating                                         2.9 out of 5 stars
# category                                              electronics
# mrp                                                         257.1
# isBestSeller                                                False
# Name: 79, dtype: object
# Unnamed: 0                                                     80
# product_link    https://www.amazon.com/Bluetooth-Speakers-Subw...
# image_link      https://m.media-amazon.com/images/I/71PT6EDOTu...
# sponsered                                                       0
# title           Bluetooth Speakers,Home Audio Sound Bars with ...
# offer_price                                                 17.99
# currency                                                        $
# rating                                         4.0 out of 5 stars
# category                                              electronics
# mrp                                                          25.1
# isBestSeller                                                False
# Name: 80, dtype: object
# Unnamed: 0                                                     81
# product_link    https://www.amazon.com/gp/slredirect/picassoRe...
# image_link      https://m.media-amazon.com/images/I/8134LE7AYm...
# sponsered                                                       0
# title           Portable Kakobor Bluetooth Speakers Portable W...
# offer_price                                                 54.99
# currency                                                        $
# rating                                         4.0 out of 5 stars
# category                                              electronics
# mrp                                                          65.9
# isBestSeller                                                False
# Name: 81, dtype: object
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-826424a4b5ee> in <module>
#     101         for index, rows in data.iterrows():
#     102             print(rows)
# --> 103             sleep(4)
#     104         pass
#
# KeyboardInterrupt:
